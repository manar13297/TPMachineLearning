# %% [markdown]
# # Les arbres de decision
# ## Objectif
#
# 1.  Comprendre l'algorithme des Arbres de décision
# 2.  Comprendre la mésure de selection d'attributs:
# > *   Information Gain
# > *   Gain Ratio
# > *   Gini index
# 3.  Créer un arbre de decision en utilisant Scikit-learn
# 4.  Utilisation des differentes metriques pour l'évaluation d'un modèle
# 4.  Optimiser les performance d'un arbre de decision
#
# ## Introduction
# Un arbre de décision est une structure arborescente semblable à un organigramme où un **nœud interne** représente une caractéristique (ou un attribut), la branche représente une règle de décision et chaque **nœud feuille** représente le résultat. Le nœud le plus élevé dans un arbre de décision est connu sous le nom de **nœud racine**.
#
# Un arbre de décision est facile à comprendre et à interpréter car il apprend à partitionner sur la base de la valeur d'attribut. Il partitionne l'arborescence de manière récursive en appelant le partitionnement récursif. Cette structure de type organigramme vous aide à prendre des décisions. C'est une visualisation comme un diagramme d'organigramme qui imite facilement la pensée au niveau humain. C'est pourquoi les arbres de décision sont faciles à comprendre et à interpréter.
# ![image-2.png](attachment:image-2.png)
#
# ## Algorithme
# 1.  Sélectionnez le meilleur attribut à l'aide des mesures de sélection d'attribut (ASM) pour fractionner les enregistrements.
# 2. Faire de cet attribut le nœud de décision et divisez l'ensemble de données en sous-ensembles plus petits.
# 3. Répéter ce processus de manière récursive pour chaque nœud enfant jusqu'à ce que l'une des conditions corresponde:
# >- Tous les tuples appartiennent à la même valeur d'attribut.
# >- Il n'y a plus d'attributs restants.
# >- Il n'y a plus d'instances.
#
# ![image-4.png](attachment:image-4.png)
#
# ## Mesures de sélection d'attribut
# La mesure de sélection d'attribut (Atribut Selection Mesure ASM) permet de sélectionner le critère de fractionnement qui partitionne les données de la meilleure manière possible. L'attribut avec le meilleur ASM sera sélectionné comme attribut de division. Dans le cas d'un attribut à valeur continue, les points de partage des branches doivent également être définis. Les mesures de sélection les plus populaires sont:
# >- le gain d'information(**Information Gain**)
# >- le ratio de gain (**Gain Ratio**)
# >- l'indice de Gini(**Gini Index**).
#
# ## Réferences:
# https://www.analyticssteps.com/blogs/decision-tree-machine-learning

# %% [markdown]
# ## Q1. Chargement des données
# 1- Construire un Dataframe ***data*** contenant les données stoker dans le fichier ***diabetes.csv***  https://www.kaggle.com/uciml/pima-indians-diabetes-database
#
# 2- visualiser ce dataframe ainsi que les diferentes mesure sur ce dataframe

# %%
#1
import pandas as pd
data = pd.read_csv("diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
#2
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ## Q2. Selection des caracteristiques
# Créer les deux dataframes:
# - X: le dataframe des entrée
# - y: la sortie (outcome)

# %%
X = data.iloc[:, 0:-1]
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y=data["Outcome"]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# ## Q3. Partitionner ces données en X_train, X_test, y_train, y_test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test , y_train , y_test = train_test_split(X , y , train_size = 0.8 , test_size = 0.2)

# %% [markdown]
# ## Q4. Création, entrainement et évaluation du modèle
# 1. Utiliser le classifieur ***DecisionTreeClassifier*** du module ***sklearn.tree*** pour initialiser et entrainer un arbre de décision
# 2. Afficher la matrice de confusion de ce modèle
# 3. Calculer les trois metrics suivante:
# >- Accuracy
# >- Prcison
# >- recall
# >- F1 score
#
# de ce modèle (voir l'article suivant: https://towardsdatascience.com/accuracy-precision-recall-or-f1-331fb37c5cb9)

# %%
from sklearn.tree import DecisionTreeClassifier

#1
tree = DecisionTreeClassifier()
tree.fit(X_train,y_train)

#2
y_pred = tree.predict(X_test)

# %%
#Matrice de confusion
from sklearn.metrics import *

cm = confusion_matrix(y_test,y_pred,labels=[0,1])
cm
# Out:
# array([[74, 25],
#        [25, 30]], dtype=int64)

# %%
TN, FP, FN, TP = cm.ravel()
TN, FP, FN, TP
# Out:
# (74, 25, 25, 30)

# %%
#Calculer les trois metrics 

Accuracy = (TP+TN)/(TN+FP+FN+TP)
Precision = TP/(TP+FP)
Recall = TP/(TP+FN)
F1_score = (2* Recall * Precision)/(Recall+Precision)

print("Accuracy = ", Accuracy)
print("Precision = ", Precision)
print('Recall = ',Recall)
print('F1_score = ', F1_score)
# Out:
# Accuracy =  0.6753246753246753
# Precision =  0.5454545454545454
# Recall =  0.5454545454545454
# F1_score =  0.5454545454545454

# %% [markdown]
# ## Q5. Visualisation d'un arbre de décision
# 1. Utiliser la fonction ***plot_tree(dt)***  de ***sklearn.tree*** pour visualiser l'arbre de décision résultante
# 2. Que remarqez-vous?

# %%
from sklearn.tree import plot_tree
plot_tree(tree)
# Out:
# [Text(137.4963641826923, 211.4, 'X[1] <= 123.5\ngini = 0.453\nsamples = 614\nvalue = [401, 213]'),
#  Text(53.670612980769235, 199.32, 'X[7] <= 28.5\ngini = 0.276\nsamples = 351\nvalue = [293, 58]'),
#  Text(24.14423076923077, 187.24, 'X[5] <= 45.4\ngini = 0.145\nsamples = 204\nvalue = [188, 16]'),
#  Text(17.70576923076923, 175.16, 'X[0] <= 7.5\ngini = 0.122\nsamples = 200\nvalue = [187, 13]'),
#  Text(14.486538461538462, 163.07999999999998, 'X[5] <= 30.95\ngini = 0.113\nsamples = 199\nvalue = [187, 12]'),
#  Text(8.048076923076923, 151.0, 'X[6] <= 0.672\ngini = 0.018\nsamples = 113\nvalue = [112, 1]'),
#  Text(4.828846153846154, 138.92000000000002, 'gini = 0.0\nsamples = 99\nvalue = [99, 0]'),
#  Text(11.267307692307693, 138.92000000000002, 'X[6] <= 0.686\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(8.048076923076923, 126.84, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(14.486538461538462, 126.84, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(20.925, 151.0, 'X[2] <= 22.0\ngini = 0.223\nsamples = 86\nvalue = [75, 11]'),
#  Text(17.70576923076923, 138.92000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(24.14423076923077, 138.92000000000002, 'X[6] <= 1.272\ngini = 0.208\nsamples = 85\nvalue = [75, 10]'),
#  Text(20.925, 126.84, 'X[6] <= 0.501\ngini = 0.191\nsamples = 84\nvalue = [75, 9]'),
#  Text(9.657692307692308, 114.75999999999999, 'X[5] <= 31.1\ngini = 0.103\nsamples = 55\nvalue = [52, 3]'),
#  Text(6.438461538461539, 102.67999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(12.876923076923077, 102.67999999999999, 'X[3] <= 25.5\ngini = 0.071\nsamples = 54\nvalue = [52, 2]'),
#  Text(9.657692307692308, 90.6, 'X[3] <= 24.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(6.438461538461539, 78.52000000000001, 'X[1] <= 112.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(3.2192307692307693, 66.44, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(9.657692307692308, 66.44, 'X[1] <= 115.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(6.438461538461539, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(12.876923076923077, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(12.876923076923077, 78.52000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(16.096153846153847, 90.6, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(32.19230769230769, 114.75999999999999, 'X[6] <= 0.544\ngini = 0.328\nsamples = 29\nvalue = [23, 6]'),
#  Text(25.753846153846155, 102.67999999999999, 'X[4] <= 147.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(22.534615384615385, 90.6, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(28.973076923076924, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(38.63076923076923, 102.67999999999999, 'X[4] <= 70.0\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(35.41153846153846, 90.6, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(41.85, 90.6, 'X[4] <= 92.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(38.63076923076923, 78.52000000000001, 'X[6] <= 0.908\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(35.41153846153846, 66.44, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(41.85, 66.44, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(45.06923076923077, 78.52000000000001, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(27.36346153846154, 126.84, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(20.925, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(30.58269230769231, 175.16, 'X[5] <= 56.15\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(27.36346153846154, 163.07999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(33.801923076923075, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(83.1969951923077, 187.24, 'X[5] <= 26.35\ngini = 0.408\nsamples = 147\nvalue = [105, 42]'),
#  Text(69.21346153846154, 175.16, 'X[5] <= 9.65\ngini = 0.054\nsamples = 36\nvalue = [35, 1]'),
#  Text(65.99423076923077, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(72.4326923076923, 163.07999999999998, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]'),
#  Text(97.18052884615385, 175.16, 'X[1] <= 101.5\ngini = 0.466\nsamples = 111\nvalue = [70, 41]'),
#  Text(78.87115384615385, 163.07999999999998, 'X[1] <= 28.5\ngini = 0.305\nsamples = 48\nvalue = [39, 9]'),
#  Text(75.65192307692308, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(82.09038461538462, 151.0, 'X[4] <= 202.5\ngini = 0.258\nsamples = 46\nvalue = [39, 7]'),
#  Text(78.87115384615385, 138.92000000000002, 'X[6] <= 1.16\ngini = 0.231\nsamples = 45\nvalue = [39, 6]'),
#  Text(75.65192307692308, 126.84, 'X[7] <= 42.5\ngini = 0.201\nsamples = 44\nvalue = [39, 5]'),
#  Text(64.38461538461539, 114.75999999999999, 'X[4] <= 88.0\ngini = 0.111\nsamples = 34\nvalue = [32, 2]'),
#  Text(57.94615384615385, 102.67999999999999, 'X[6] <= 0.182\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(54.72692307692308, 90.6, 'X[2] <= 66.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(51.50769230769231, 78.52000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(57.94615384615385, 78.52000000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(61.16538461538462, 90.6, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(70.82307692307693, 102.67999999999999, 'X[5] <= 43.85\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(67.60384615384615, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(74.0423076923077, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(86.91923076923078, 114.75999999999999, 'X[1] <= 96.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(83.7, 102.67999999999999, 'X[3] <= 24.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(80.48076923076923, 90.6, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(86.91923076923078, 90.6, 'X[6] <= 0.159\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(83.7, 78.52000000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(90.13846153846154, 78.52000000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(90.13846153846154, 102.67999999999999, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(82.09038461538462, 126.84, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(85.30961538461538, 138.92000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(115.48990384615385, 163.07999999999998, 'X[6] <= 0.22\ngini = 0.5\nsamples = 63\nvalue = [31, 32]'),
#  Text(104.625, 151.0, 'X[5] <= 28.1\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(101.40576923076924, 138.92000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(107.84423076923078, 138.92000000000002, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(126.3548076923077, 151.0, 'X[1] <= 119.5\ngini = 0.486\nsamples = 53\nvalue = [22, 31]'),
#  Text(114.28269230769232, 138.92000000000002, 'X[2] <= 86.0\ngini = 0.444\nsamples = 42\nvalue = [14, 28]'),
#  Text(106.23461538461538, 126.84, 'X[2] <= 58.0\ngini = 0.342\nsamples = 32\nvalue = [7, 25]'),
#  Text(99.79615384615386, 114.75999999999999, 'X[1] <= 115.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(96.57692307692308, 102.67999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(103.01538461538462, 102.67999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(112.67307692307693, 114.75999999999999, 'X[6] <= 0.241\ngini = 0.285\nsamples = 29\nvalue = [5, 24]'),
#  Text(109.45384615384616, 102.67999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(115.8923076923077, 102.67999999999999, 'X[7] <= 53.5\ngini = 0.245\nsamples = 28\nvalue = [4, 24]'),
#  Text(107.84423076923078, 90.6, 'X[0] <= 0.5\ngini = 0.153\nsamples = 24\nvalue = [2, 22]'),
#  Text(101.40576923076924, 78.52000000000001, 'X[4] <= 115.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(98.18653846153846, 66.44, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(104.625, 66.44, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(114.28269230769232, 78.52000000000001, 'X[7] <= 29.5\ngini = 0.087\nsamples = 22\nvalue = [1, 21]'),
#  Text(111.06346153846154, 66.44, 'X[3] <= 12.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(107.84423076923078, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(114.28269230769232, 54.359999999999985, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(117.50192307692308, 66.44, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(123.94038461538462, 90.6, 'X[0] <= 4.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(120.72115384615385, 78.52000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(127.15961538461539, 78.52000000000001, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(122.33076923076923, 126.84, 'X[3] <= 18.0\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(119.11153846153846, 114.75999999999999, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(125.55000000000001, 114.75999999999999, 'X[1] <= 104.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(122.33076923076923, 102.67999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(128.76923076923077, 102.67999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(138.4269230769231, 138.92000000000002, 'X[7] <= 46.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(135.2076923076923, 126.84, 'X[2] <= 65.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(131.98846153846154, 114.75999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(138.4269230769231, 114.75999999999999, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(141.64615384615385, 126.84, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(221.3221153846154, 199.32, 'X[5] <= 29.95\ngini = 0.484\nsamples = 263\nvalue = [108, 155]'),
#  Text(164.98557692307693, 187.24, 'X[0] <= 1.5\ngini = 0.45\nsamples = 76\nvalue = [50, 26]'),
#  Text(151.30384615384617, 175.16, 'X[1] <= 125.0\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(148.0846153846154, 163.07999999999998, 'X[7] <= 33.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(144.8653846153846, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(151.30384615384617, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(154.52307692307693, 163.07999999999998, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(178.6673076923077, 175.16, 'X[7] <= 60.5\ngini = 0.492\nsamples = 57\nvalue = [32, 25]'),
#  Text(175.44807692307694, 163.07999999999998, 'X[1] <= 154.5\ngini = 0.5\nsamples = 50\nvalue = [25, 25]'),
#  Text(157.7423076923077, 151.0, 'X[1] <= 126.0\ngini = 0.48\nsamples = 35\nvalue = [21, 14]'),
#  Text(151.30384615384617, 138.92000000000002, 'X[6] <= 0.196\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(148.0846153846154, 126.84, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(154.52307692307693, 126.84, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(164.18076923076924, 138.92000000000002, 'X[2] <= 56.0\ngini = 0.428\nsamples = 29\nvalue = [20, 9]'),
#  Text(160.96153846153845, 126.84, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(167.4, 126.84, 'X[3] <= 28.5\ngini = 0.384\nsamples = 27\nvalue = [20, 7]'),
#  Text(160.96153846153845, 114.75999999999999, 'X[1] <= 135.0\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(157.7423076923077, 102.67999999999999, 'X[5] <= 28.2\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(154.52307692307693, 90.6, 'X[1] <= 133.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(151.30384615384617, 78.52000000000001, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(157.7423076923077, 78.52000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(160.96153846153845, 90.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(164.18076923076924, 102.67999999999999, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(173.83846153846156, 114.75999999999999, 'X[5] <= 28.45\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(170.61923076923077, 102.67999999999999, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(177.05769230769232, 102.67999999999999, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(193.15384615384616, 151.0, 'X[2] <= 81.0\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(186.7153846153846, 138.92000000000002, 'X[1] <= 160.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(183.49615384615385, 126.84, 'X[2] <= 69.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(180.27692307692308, 114.75999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(186.7153846153846, 114.75999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(189.9346153846154, 126.84, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(199.5923076923077, 138.92000000000002, 'X[1] <= 159.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(196.37307692307692, 126.84, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(202.81153846153848, 126.84, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(181.88653846153846, 163.07999999999998, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(277.65865384615387, 187.24, 'X[1] <= 155.5\ngini = 0.428\nsamples = 187\nvalue = [58, 129]'),
#  Text(235.80865384615385, 175.16, 'X[7] <= 24.5\ngini = 0.489\nsamples = 113\nvalue = [48, 65]'),
#  Text(212.46923076923076, 163.07999999999998, 'X[2] <= 53.0\ngini = 0.408\nsamples = 21\nvalue = [15, 6]'),
#  Text(209.25, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(215.68846153846155, 151.0, 'X[6] <= 1.141\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(212.46923076923076, 138.92000000000002, 'X[0] <= 0.5\ngini = 0.278\nsamples = 18\nvalue = [15, 3]'),
#  Text(209.25, 126.84, 'X[5] <= 33.35\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(206.03076923076924, 114.75999999999999, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(212.46923076923076, 114.75999999999999, 'X[3] <= 50.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(209.25, 102.67999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(215.68846153846155, 102.67999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(215.68846153846155, 126.84, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(218.90769230769232, 138.92000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(259.1480769230769, 163.07999999999998, 'X[6] <= 0.719\ngini = 0.46\nsamples = 92\nvalue = [33, 59]'),
#  Text(238.22307692307692, 151.0, 'X[2] <= 67.0\ngini = 0.487\nsamples = 74\nvalue = [31, 43]'),
#  Text(225.34615384615387, 138.92000000000002, 'X[6] <= 0.108\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(222.12692307692308, 126.84, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(228.56538461538463, 126.84, 'X[1] <= 130.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(225.34615384615387, 114.75999999999999, 'X[6] <= 0.326\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(222.12692307692308, 102.67999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(228.56538461538463, 102.67999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(231.7846153846154, 114.75999999999999, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(251.10000000000002, 138.92000000000002, 'X[7] <= 40.5\ngini = 0.499\nsamples = 60\nvalue = [29, 31]'),
#  Text(241.4423076923077, 126.84, 'X[5] <= 47.7\ngini = 0.467\nsamples = 35\nvalue = [22, 13]'),
#  Text(238.22307692307692, 114.75999999999999, 'X[4] <= 219.0\ngini = 0.43\nsamples = 32\nvalue = [22, 10]'),
#  Text(235.00384615384615, 102.67999999999999, 'X[0] <= 2.5\ngini = 0.473\nsamples = 26\nvalue = [16, 10]'),
#  Text(231.7846153846154, 90.6, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(238.22307692307692, 90.6, 'X[5] <= 31.45\ngini = 0.496\nsamples = 22\nvalue = [12, 10]'),
#  Text(235.00384615384615, 78.52000000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(241.4423076923077, 78.52000000000001, 'X[2] <= 86.0\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(238.22307692307692, 66.44, 'X[0] <= 9.5\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(235.00384615384615, 54.359999999999985, 'X[6] <= 0.562\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(228.56538461538463, 42.28, 'X[2] <= 69.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(225.34615384615387, 30.19999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(231.7846153846154, 30.19999999999999, 'X[7] <= 26.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(228.56538461538463, 18.120000000000005, 'X[1] <= 131.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(225.34615384615387, 6.039999999999992, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(231.7846153846154, 6.039999999999992, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(235.00384615384615, 18.120000000000005, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(241.4423076923077, 42.28, 'X[7] <= 38.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(238.22307692307692, 30.19999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(244.66153846153847, 30.19999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(241.4423076923077, 54.359999999999985, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(244.66153846153847, 66.44, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(241.4423076923077, 102.67999999999999, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(244.66153846153847, 114.75999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(260.7576923076923, 126.84, 'X[3] <= 16.5\ngini = 0.403\nsamples = 25\nvalue = [7, 18]'),
#  Text(251.10000000000002, 114.75999999999999, 'X[7] <= 44.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(247.88076923076923, 102.67999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(254.31923076923078, 102.67999999999999, 'X[6] <= 0.132\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(251.10000000000002, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(257.53846153846155, 90.6, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(270.4153846153846, 114.75999999999999, 'X[5] <= 31.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(267.19615384615383, 102.67999999999999, 'X[7] <= 44.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(263.9769230769231, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(270.4153846153846, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(273.6346153846154, 102.67999999999999, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(280.07307692307694, 151.0, 'X[1] <= 152.5\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(276.8538461538462, 138.92000000000002, 'X[6] <= 1.586\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(273.6346153846154, 126.84, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(280.07307692307694, 126.84, 'X[3] <= 17.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(276.8538461538462, 114.75999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(283.2923076923077, 114.75999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(283.2923076923077, 138.92000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(319.50865384615383, 175.16, 'X[4] <= 629.5\ngini = 0.234\nsamples = 74\nvalue = [10, 64]'),
#  Text(310.65576923076924, 163.07999999999998, 'X[6] <= 0.343\ngini = 0.2\nsamples = 71\nvalue = [8, 63]'),
#  Text(302.60769230769233, 151.0, 'X[5] <= 35.3\ngini = 0.346\nsamples = 27\nvalue = [6, 21]'),
#  Text(296.1692307692308, 138.92000000000002, 'X[5] <= 34.15\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(292.95, 126.84, 'X[0] <= 4.0\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(289.7307692307692, 114.75999999999999, 'X[6] <= 0.247\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(286.51153846153846, 102.67999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(292.95, 102.67999999999999, 'X[5] <= 33.45\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(289.7307692307692, 90.6, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(296.1692307692308, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(296.1692307692308, 114.75999999999999, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(299.38846153846157, 126.84, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(309.04615384615386, 138.92000000000002, 'X[3] <= 41.0\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(305.8269230769231, 126.84, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(312.2653846153846, 126.84, 'X[5] <= 45.6\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(309.04615384615386, 114.75999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(315.4846153846154, 114.75999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(318.70384615384614, 151.0, 'X[7] <= 48.0\ngini = 0.087\nsamples = 44\nvalue = [2, 42]'),
#  Text(315.4846153846154, 138.92000000000002, 'gini = 0.0\nsamples = 35\nvalue = [0, 35]'),
#  Text(321.9230769230769, 138.92000000000002, 'X[0] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(318.70384615384614, 126.84, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(325.1423076923077, 126.84, 'X[2] <= 69.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(321.9230769230769, 114.75999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(328.3615384615385, 114.75999999999999, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(328.3615384615385, 163.07999999999998, 'X[4] <= 795.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(325.1423076923077, 151.0, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(331.58076923076925, 151.0, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(40,40))
plot_tree(tree , feature_names=data.columns[:-1] , class_names=['0','1'] ,fontsize=20 )
plt.show()

# %% [markdown]
# ## Q6. Optimisation les performance d'un arbre de décision
# 1. Créer deux arbres de décisions avec les paramétres suisvants:
# >- Arbre 1: ( ASM = entropy , max_depth: 3)
# >- Arbre 2: ( ASM = gini , max_depth: 3)
#
# > NB: utiliser la documentation https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
#
# 2. Comparer les resultats avec celles de la question Q5

# %%
arbre1 = DecisionTreeClassifier(criterion="entropy" , max_depth=3).fit(X_train,y_train)
arbre2 = DecisionTreeClassifier(criterion="gini" , max_depth=3).fit(X_train,y_train)

plt.figure(figsize=(30,30))

plot_tree(arbre1 , feature_names=data.columns[:-1] , class_names=['0','1'],fontsize=20,filled=True)
# Out:
# [Text(837.0, 1426.95, 'Glucose <= 123.5\nentropy = 0.931\nsamples = 614\nvalue = [401, 213]\nclass = 0'),
#  Text(418.5, 1019.25, 'BMI <= 26.45\nentropy = 0.647\nsamples = 351\nvalue = [293, 58]\nclass = 0'),
#  Text(209.25, 611.55, 'Glucose <= 106.5\nentropy = 0.136\nsamples = 105\nvalue = [103, 2]\nclass = 0'),
#  Text(104.625, 203.8499999999999, 'entropy = 0.0\nsamples = 69\nvalue = [69, 0]\nclass = 0'),
#  Text(313.875, 203.8499999999999, 'entropy = 0.31\nsamples = 36\nvalue = [34, 2]\nclass = 0'),
#  Text(627.75, 611.55, 'Age <= 28.5\nentropy = 0.774\nsamples = 246\nvalue = [190, 56]\nclass = 0'),
#  Text(523.125, 203.8499999999999, 'entropy = 0.503\nsamples = 135\nvalue = [120, 15]\nclass = 0'),
#  Text(732.375, 203.8499999999999, 'entropy = 0.95\nsamples = 111\nvalue = [70, 41]\nclass = 0'),
#  Text(1255.5, 1019.25, 'BMI <= 29.95\nentropy = 0.977\nsamples = 263\nvalue = [108, 155]\nclass = 1'),
#  Text(1046.25, 611.55, 'Pregnancies <= 1.5\nentropy = 0.927\nsamples = 76\nvalue = [50, 26]\nclass = 0'),
#  Text(941.625, 203.8499999999999, 'entropy = 0.297\nsamples = 19\nvalue = [18, 1]\nclass = 0'),
#  Text(1150.875, 203.8499999999999, 'entropy = 0.989\nsamples = 57\nvalue = [32, 25]\nclass = 0'),
#  Text(1464.75, 611.55, 'Glucose <= 155.5\nentropy = 0.893\nsamples = 187\nvalue = [58, 129]\nclass = 1'),
#  Text(1360.125, 203.8499999999999, 'entropy = 0.984\nsamples = 113\nvalue = [48, 65]\nclass = 1'),
#  Text(1569.375, 203.8499999999999, 'entropy = 0.571\nsamples = 74\nvalue = [10, 64]\nclass = 1')]

# %%
plt.figure(figsize=(20,20))
plot_tree(arbre2 , feature_names=data.columns[:-1] , class_names=['0','1'],fontsize=15,filled=True)
# Out:
# [Text(558.0, 951.3000000000001, 'Glucose <= 123.5\ngini = 0.453\nsamples = 614\nvalue = [401, 213]\nclass = 0'),
#  Text(279.0, 679.5, 'Age <= 28.5\ngini = 0.276\nsamples = 351\nvalue = [293, 58]\nclass = 0'),
#  Text(139.5, 407.70000000000005, 'BMI <= 45.4\ngini = 0.145\nsamples = 204\nvalue = [188, 16]\nclass = 0'),
#  Text(69.75, 135.89999999999998, 'gini = 0.122\nsamples = 200\nvalue = [187, 13]\nclass = 0'),
#  Text(209.25, 135.89999999999998, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(418.5, 407.70000000000005, 'BMI <= 26.35\ngini = 0.408\nsamples = 147\nvalue = [105, 42]\nclass = 0'),
#  Text(348.75, 135.89999999999998, 'gini = 0.054\nsamples = 36\nvalue = [35, 1]\nclass = 0'),
#  Text(488.25, 135.89999999999998, 'gini = 0.466\nsamples = 111\nvalue = [70, 41]\nclass = 0'),
#  Text(837.0, 679.5, 'BMI <= 29.95\ngini = 0.484\nsamples = 263\nvalue = [108, 155]\nclass = 1'),
#  Text(697.5, 407.70000000000005, 'Pregnancies <= 1.5\ngini = 0.45\nsamples = 76\nvalue = [50, 26]\nclass = 0'),
#  Text(627.75, 135.89999999999998, 'gini = 0.1\nsamples = 19\nvalue = [18, 1]\nclass = 0'),
#  Text(767.25, 135.89999999999998, 'gini = 0.492\nsamples = 57\nvalue = [32, 25]\nclass = 0'),
#  Text(976.5, 407.70000000000005, 'Glucose <= 155.5\ngini = 0.428\nsamples = 187\nvalue = [58, 129]\nclass = 1'),
#  Text(906.75, 135.89999999999998, 'gini = 0.489\nsamples = 113\nvalue = [48, 65]\nclass = 1'),
#  Text(1046.25, 135.89999999999998, 'gini = 0.234\nsamples = 74\nvalue = [10, 64]\nclass = 1')]

# %% [markdown]
# ## Q7. peut-on réduire le nombre de caractèristiques utilisé dans ce modèle pour obtrnir les meme performances?

# %%
#Oui

# %% [markdown]
# #### Q8. utilisation du modèle
# Mr Rachid a fait un bilon et a obtenu les resu Après un bilon Mr
# - Age: 22
# - Glucose: 79
# - BloodPressure: 69
# - Insulin: 31
# - BMI: 0.4
#
# Mr Rachid a-t-il un diabéte?

# %%
Pregnancies = data.describe().mean()['Pregnancies']
SkinThickness = data.describe().mean()['SkinThickness']
DiabetesPedigreeFunction = data.describe().mean()['DiabetesPedigreeFunction']

# %%
donnees = pd.DataFrame([{'Pregnancies':Pregnancies , 'Glucose':79,
                          'BloodPressure':69,'SkinThickness':SkinThickness,
                          'Insulin':31,'BMI':0.4,'DiabetesPedigreeFunction':DiabetesPedigreeFunction,
                           'Age':22}])
pred=tree.predict(donnees.to_numpy())
donnees['prediction']=pred
donnees['diabete'] = 'il a un diabete'
donnees
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0   100.276829       79             69     119.811084       31  0.4
#
#    DiabetesPedigreeFunction  Age  prediction          diabete
# 0                 96.567963   22           1  il a un diabete
